# %%
from atmons import *
import matplotlib.pyplot as plt

# %%
config, grid = loader()
# config['spec_key'] = 'be'
config['spec_key'] = 'wfc'
config['chem'] = 's001'

config['m_ns'] = 1.5
config['r_ns'] = 13.16
config['v_rot'] = 700

grid['n_nu'] = 500
grid['n_theta'] = 6
grid['n_phi'] = 12
grid['rng_erg'] = [3.0, 20.0]

dumper('lfc', config, grid)
config, grid = loader("lfc")

# %%
SizeA = GraphSize(x_range=(0.0,1.1), y_range=(1.3,1.9),  figsize=(7,6))
SizeB = GraphSize(x_range=(0.0,1.1), y_range=(0.07,0.27), figsize=(7,6))
I_arr = [0, 45, 90]
Fkey_arr = [1, 2]
for k in range(len(Fkey_arr)):
    config['flux_key'] = Fkey_arr[k]
    flux_key = config['flux_key'] 
    for i in range(len(I_arr)):
        config['i_ang'] = I_arr[i]
        W_arr, Fc_arr, L_arr = [], [], []
        ns = NeurtonStar(config, grid)
        burst = ns.burst()
        counter = 0
        for shot in burst:
            #print(f"{counter} | {shot.lum}")
            L_arr.append(shot.lum)
            Fc_arr.append(shot.fc)
            W_arr.append(shot.w)
            counter += 1
            percent = (k*3*N_MODEL+i*N_MODEL+(counter))/(2*3*N_MODEL) * 100
            print(f"Downloading...{percent:.2f}%: {k+1} graph, {i+1} line, {counter} shot ")

        data_w = GraphData(L_arr, W_arr, tex_mode=True,
                            ascii_label=f"i = {I_arr[i]} deg",
                            latex_label=f"$i = {I_arr[i]}, deg$")
        data_fc = GraphData(L_arr, Fc_arr, tex_mode=True,
                            ascii_label=f"i = {I_arr[i]} deg",
                            latex_label=f"$i = {I_arr[i]}, deg$")
        if flux_key==1:
            DataBaseFig8A.DB.append(data_fc)
            DataBaseFig8B.DB.append(data_w)
        else:
            DataBaseFig9A.DB.append(data_fc)
            DataBaseFig9B.DB.append(data_w)
    
    if flux_key == 1:
        Graph_8A = GraphOld(DataBaseFig8A, SizeA, LegendStyle)
        Graph_8B = GraphOld(DataBaseFig8B, SizeB, LegendStyle)
        #Graph_8A.draw_picture(save=True, draw=False) 
        #Graph_8B.draw_picture(save=True, draw=False) 
    else:
        Graph_9A = GraphOld(DataBaseFig9A, SizeA, LegendStyle)
        Graph_9B = GraphOld(DataBaseFig9B, SizeB, LegendStyle)
        #Graph_9A.draw_picture(save=True, draw=False) 
        #Graph_9B.draw_picture(save=True, draw=False) 

Graph_arr = [Graph_8A, Graph_8B, Graph_9A, Graph_9B]
for graph in Graph_arr:
    graph.draw_picture(save=True, draw=False) 
    graph.draw_table()
# Out:
# Downloading...0.72%: 1 graph, 1 line, 1 shot
# Downloading...1.45%: 1 graph, 1 line, 2 shot
# Downloading...2.17%: 1 graph, 1 line, 3 shot
# Downloading...2.90%: 1 graph, 1 line, 4 shot
# Downloading...3.62%: 1 graph, 1 line, 5 shot
# Downloading...4.35%: 1 graph, 1 line, 6 shot
# Downloading...5.07%: 1 graph, 1 line, 7 shot
# Downloading...5.80%: 1 graph, 1 line, 8 shot
# Downloading...6.52%: 1 graph, 1 line, 9 shot
# Downloading...7.25%: 1 graph, 1 line, 10 shot
# Downloading...7.97%: 1 graph, 1 line, 11 shot
# Downloading...8.70%: 1 graph, 1 line, 12 shot
# Downloading...9.42%: 1 graph, 1 line, 13 shot
# Downloading...10.14%: 1 graph, 1 line, 14 shot
# Downloading...10.87%: 1 graph, 1 line, 15 shot
# Downloading...11.59%: 1 graph, 1 line, 16 shot
# Downloading...12.32%: 1 graph, 1 line, 17 shot
# Downloading...13.04%: 1 graph, 1 line, 18 shot
# Downloading...13.77%: 1 graph, 1 line, 19 shot
# Downloading...14.49%: 1 graph, 1 line, 20 shot
# Downloading...15.22%: 1 graph, 1 line, 21 shot
# Downloading...15.94%: 1 graph, 1 line, 22 shot
# Downloading...16.67%: 1 graph, 1 line, 23 shot
# Downloading...17.39%: 1 graph, 2 line, 1 shot
# Downloading...18.12%: 1 graph, 2 line, 2 shot
# Downloading...18.84%: 1 graph, 2 line, 3 shot
# Downloading...19.57%: 1 graph, 2 line, 4 shot
# Downloading...20.29%: 1 graph, 2 line, 5 shot
# Downloading...21.01%: 1 graph, 2 line, 6 shot
# Downloading...21.74%: 1 graph, 2 line, 7 shot
# Downloading...22.46%: 1 graph, 2 line, 8 shot
# Downloading...23.19%: 1 graph, 2 line, 9 shot
# Downloading...23.91%: 1 graph, 2 line, 10 shot
# Downloading...24.64%: 1 graph, 2 line, 11 shot
# Downloading...25.36%: 1 graph, 2 line, 12 shot
# Downloading...26.09%: 1 graph, 2 line, 13 shot
# Downloading...26.81%: 1 graph, 2 line, 14 shot
# Downloading...27.54%: 1 graph, 2 line, 15 shot
# Downloading...28.26%: 1 graph, 2 line, 16 shot
# Downloading...28.99%: 1 graph, 2 line, 17 shot
# Downloading...29.71%: 1 graph, 2 line, 18 shot
# Downloading...30.43%: 1 graph, 2 line, 19 shot
# Downloading...31.16%: 1 graph, 2 line, 20 shot
# Downloading...31.88%: 1 graph, 2 line, 21 shot
# Downloading...32.61%: 1 graph, 2 line, 22 shot
# Downloading...33.33%: 1 graph, 2 line, 23 shot
# Downloading...34.06%: 1 graph, 3 line, 1 shot
# Downloading...34.78%: 1 graph, 3 line, 2 shot
# Downloading...35.51%: 1 graph, 3 line, 3 shot
# Downloading...36.23%: 1 graph, 3 line, 4 shot
# Downloading...36.96%: 1 graph, 3 line, 5 shot
# Downloading...37.68%: 1 graph, 3 line, 6 shot
# Downloading...38.41%: 1 graph, 3 line, 7 shot
# Downloading...39.13%: 1 graph, 3 line, 8 shot
# Downloading...39.86%: 1 graph, 3 line, 9 shot
# Downloading...40.58%: 1 graph, 3 line, 10 shot
# Downloading...41.30%: 1 graph, 3 line, 11 shot
# Downloading...42.03%: 1 graph, 3 line, 12 shot
# Downloading...42.75%: 1 graph, 3 line, 13 shot
# Downloading...43.48%: 1 graph, 3 line, 14 shot
# Downloading...44.20%: 1 graph, 3 line, 15 shot
# Downloading...44.93%: 1 graph, 3 line, 16 shot
# Downloading...45.65%: 1 graph, 3 line, 17 shot
# Downloading...46.38%: 1 graph, 3 line, 18 shot
# Downloading...47.10%: 1 graph, 3 line, 19 shot
# Downloading...47.83%: 1 graph, 3 line, 20 shot
# Downloading...48.55%: 1 graph, 3 line, 21 shot
# Downloading...49.28%: 1 graph, 3 line, 22 shot
# Downloading...50.00%: 1 graph, 3 line, 23 shot
# Downloading...50.72%: 2 graph, 1 line, 1 shot
# Downloading...51.45%: 2 graph, 1 line, 2 shot
# Downloading...52.17%: 2 graph, 1 line, 3 shot
# Downloading...52.90%: 2 graph, 1 line, 4 shot
# Downloading...53.62%: 2 graph, 1 line, 5 shot
# Downloading...54.35%: 2 graph, 1 line, 6 shot
# Downloading...55.07%: 2 graph, 1 line, 7 shot
# Downloading...55.80%: 2 graph, 1 line, 8 shot
# Downloading...56.52%: 2 graph, 1 line, 9 shot
# Downloading...57.25%: 2 graph, 1 line, 10 shot
# incorrectly flux
# Downloading...67.39%: 2 graph, 2 line, 1 shot
# Downloading...68.12%: 2 graph, 2 line, 2 shot
# Downloading...68.84%: 2 graph, 2 line, 3 shot
# Downloading...69.57%: 2 graph, 2 line, 4 shot
# Downloading...70.29%: 2 graph, 2 line, 5 shot
# Downloading...71.01%: 2 graph, 2 line, 6 shot
# Downloading...71.74%: 2 graph, 2 line, 7 shot
# Downloading...72.46%: 2 graph, 2 line, 8 shot
# Downloading...73.19%: 2 graph, 2 line, 9 shot
# Downloading...73.91%: 2 graph, 2 line, 10 shot
# incorrectly flux
# Downloading...84.06%: 2 graph, 3 line, 1 shot
# Downloading...84.78%: 2 graph, 3 line, 2 shot
# Downloading...85.51%: 2 graph, 3 line, 3 shot
# Downloading...86.23%: 2 graph, 3 line, 4 shot
# Downloading...86.96%: 2 graph, 3 line, 5 shot
# Downloading...87.68%: 2 graph, 3 line, 6 shot
# Downloading...88.41%: 2 graph, 3 line, 7 shot
# Downloading...89.13%: 2 graph, 3 line, 8 shot
# Downloading...89.86%: 2 graph, 3 line, 9 shot
# Downloading...90.58%: 2 graph, 3 line, 10 shot
# incorrectly flux
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#                                       F(theta)/F_Edd(theta) = const, Fig.8.a
# ┏━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃    ┃                        ┃ Colour correction factor  ┃ Colour correction factor  ┃ Colour correction factor  ┃
# ┃  N ┃ L(nu_cr, i) / L_Edd(0) ┃      f_c | i = 0 deg      ┃     f_c | i = 45 deg      ┃     f_c | i = 90 deg      ┃
# ┡━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │  1 │  0.06935331701983917   │    1.4193224550400003     │    1.4451083084800003     │    1.4738678451200002     │
# │  2 │   0.1110727959810416   │    1.4037630131200003     │    1.4277332531200002     │       1.45427620608       │
# │  3 │   0.1542915770641585   │    1.3972334566400002     │    1.4198650752000002     │    1.4447988761600001     │
# │  4 │  0.24361818510719604   │    1.3956031462400003     │    1.4165299916800003     │    1.4393947238400002     │
# │  5 │  0.33639867840122933   │    1.4044239718400005     │    1.4250035225600002     │       1.4474259328        │
# │  6 │   0.4296771939557727   │    1.4161342182400005     │    1.4359425638400003     │       1.45740438272       │
# │  7 │   0.4770754439157864   │    1.4248619468800003     │    1.4443124556800004     │       1.46532282112       │
# │  8 │   0.5237871534079239   │    1.4344933248000002     │       1.45359609344       │    1.4741657702400004     │
# │  9 │   0.572718255693057    │       1.44714731008       │    1.4659905356800003     │    1.4862212326400002     │
# │  7 │   0.5825486453959603   │      0.219528297472       │      0.192080630784       │    0.16442702745600002    │
# │  8 │   0.6411993648326023   │    0.20689459712000002    │      0.179605982208       │    0.15231324057600001    │
# │  9 │   0.7009965687924304   │    0.19131625574400005    │      0.163957060608       │       0.13691021824       │
# │ 10 │   0.7632774462874858   │    0.16753253068800003    │      0.138971794432       │      0.111475805184       │
# └────┴────────────────────────┴───────────────────────────┴───────────────────────────┴───────────────────────────┘

# %%
config, grid = loader()
config['spec_key'] = 'be'
# config['spec_key'] = 'wfc'
config['chem'] = 's001'

config['m_ns'] = 1.5
config['r_ns'] = 13.16
config['v_rot'] = 700

grid['n_nu'] = 500
grid['n_theta'] = 6
grid['n_phi'] = 12
grid['rng_erg'] = [3.0, 20.0]

dumper('lfc', config, grid)
config, grid = loader("lfc")

# %%
# SizeA = GraphSize(x_range=(0.0,1.1), y_range=(1.6, 2.3),  figsize=(7,6))
# SizeB = GraphSize(x_range=(0.0,1.1), y_range=(0.03, 0.13), figsize=(7,6))
SizeA = GraphSize(x_range=(0.0,1.1), y_range=(1.3,1.9),  figsize=(7,6))
SizeB = GraphSize(x_range=(0.0,1.1), y_range=(0.07,0.27), figsize=(7,6))

I_arr = [0, 45, 90]
Fkey_arr = [1, 2]
for k in range(len(Fkey_arr)):
    config['flux_key'] = Fkey_arr[k]
    flux_key = config['flux_key'] 
    for i in range(len(I_arr)):
        config['i_ang'] = I_arr[i]
        W_arr, Fc_arr, L_arr = [], [], []
        ns = NeurtonStar(config, grid)
        burst = ns.burst()
        counter = 0
        for shot in burst:
            #print(f"{counter} | {shot.lum}")
            L_arr.append(shot.lum)
            Fc_arr.append(shot.fc)
            W_arr.append(shot.w)
            counter += 1
            percent = (k*3*N_MODEL+i*N_MODEL+(counter))/(2*3*N_MODEL) * 100
            print(f"Downloading...{percent:.2f}%: {k+1} graph, {i+1} line, {counter} shot ")

        data_w = GraphData(L_arr, W_arr, tex_mode=True,
                            ascii_label=f"i = {I_arr[i]} deg",
                            latex_label=f"$i = {I_arr[i]}, deg$")
        data_fc = GraphData(L_arr, Fc_arr, tex_mode=True,
                            ascii_label=f"i = {I_arr[i]} deg",
                            latex_label=f"$i = {I_arr[i]}, deg$")
        if flux_key==1:
            DataBaseFig8A.DB.append(data_fc)
            DataBaseFig8B.DB.append(data_w)
        else:
            DataBaseFig9A.DB.append(data_fc)
            DataBaseFig9B.DB.append(data_w)
    
    if flux_key == 1:
        Graph_8A = GraphOld(DataBaseFig8A, SizeA, LegendStyle)
        Graph_8B = GraphOld(DataBaseFig8B, SizeB, LegendStyle)
        #Graph_8A.draw_picture(save=True, draw=False) 
        #Graph_8B.draw_picture(save=True, draw=False) 
    else:
        Graph_9A = GraphOld(DataBaseFig9A, SizeA, LegendStyle)
        Graph_9B = GraphOld(DataBaseFig9B, SizeB, LegendStyle)
        #Graph_9A.draw_picture(save=True, draw=False) 
        #Graph_9B.draw_picture(save=True, draw=False) 

Graph_arr = [Graph_8A, Graph_8B, Graph_9A, Graph_9B]
for graph in Graph_arr:
    graph.draw_picture(save=True, draw=False) 
    graph.draw_table()
